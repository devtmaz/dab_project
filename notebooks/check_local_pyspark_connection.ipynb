# %%
import findspark
import os

from pyspark.sql import SparkSession

env_vars = [
    "SPARK_HOME",
    # "HADOOP_HOME",
    "JAVA_HOME"
]
for var in env_vars:
    print(f"env[{var}] = {os.environ.get(var, '<EMPTY>')}")

findspark.init()

# Create Spark session with Windows-compatible settings
spark = (SparkSession.builder
    .appName("NotebookTest")
    .getOrCreate())

print("Spark Version:", spark.version)
print("Master:", spark.sparkContext.master)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 import findspark
#       2 import os
#       3
# ----> 4 from pyspark.sql import SparkSession
#       5
#       6 env_vars = [
#       7     "SPARK_HOME",
#
# File d:\Learning And Development\Databricks\Declarative Automation Bundles\Course CI-CD with DAB\dab_project\.venv_pyspark\Lib\site-packages\pyspark\__init__.py:148
#     145 from pyspark.context import SparkContext
#     147 # for back compatibility
# --> 148 from pyspark.sql import SQLContext, HiveContext, Row  # noqa: F401
#     150 __all__ = [
#     151     "SparkConf",
#     152     "SparkContext",
#    (...)    172     "__version__",
#     173 ]
#
# File d:\Learning And Development\Databricks\Declarative Automation Bundles\Course CI-CD with DAB\dab_project\.venv_pyspark\Lib\site-packages\pyspark\sql\__init__.py:43
#      18 """
#      19 Important classes of Spark SQL and DataFrames:
#      20
#    (...)     40       For working with window functions.
#      41 """
#      42 from pyspark.sql.types import Row
# ---> 43 from pyspark.sql.context import SQLContext, HiveContext, UDFRegistration, UDTFRegistration
#      44 from pyspark.sql.session import SparkSession
#      45 from pyspark.sql.column import Column
#
# File d:\Learning And Development\Databricks\Declarative Automation Bundles\Course CI-CD with DAB\dab_project\.venv_pyspark\Lib\site-packages\pyspark\sql\context.py:39
#      37 from pyspark import since, _NoValue
#      38 from pyspark._globals import _NoValueType
# ---> 39 from pyspark.sql.session import _monkey_patch_RDD, SparkSession
#      40 from pyspark.sql.dataframe import DataFrame
#      41 from pyspark.sql.readwriter import DataFrameReader
#
# File d:\Learning And Development\Databricks\Declarative Automation Bundles\Course CI-CD with DAB\dab_project\.venv_pyspark\Lib\site-packages\pyspark\sql\session.py:48
#      46 from pyspark.sql.conf import RuntimeConfig
#      47 from pyspark.sql.dataframe import DataFrame
# ---> 48 from pyspark.sql.functions import lit
#      49 from pyspark.sql.pandas.conversion import SparkConversionMixin
#      50 from pyspark.sql.readwriter import DataFrameReader
#
# File d:\Learning And Development\Databricks\Declarative Automation Bundles\Course CI-CD with DAB\dab_project\.venv_pyspark\Lib\site-packages\pyspark\sql\functions\__init__.py:20
#       1 #
#       2 # Licensed to the Apache Software Foundation (ASF) under one or more
#       3 # contributor license agreements.  See the NOTICE file distributed with
#    (...)     15 # limitations under the License.
#      16 #
#      18 """PySpark Functions"""
# ---> 20 from pyspark.sql.functions.builtin import *  # noqa: F401,F403
#      21 from pyspark.sql.functions import partitioning  # noqa: F401,F403
#
# File d:\Learning And Development\Databricks\Declarative Automation Bundles\Course CI-CD with DAB\dab_project\.venv_pyspark\Lib\site-packages\pyspark\sql\functions\builtin.py:49
#      45 from pyspark.sql.types import ArrayType, DataType, StringType, StructType, _from_numpy_type
#      46
#      47 # Keep UserDefinedFunction import for backwards compatible import; moved in SPARK-22409
#      48 from pyspark.sql.udf import UserDefinedFunction, _create_py_udf  # noqa: F401
# ---> 49 from pyspark.sql.udtf import AnalyzeArgument, AnalyzeResult  # noqa: F401
#      50 from pyspark.sql.udtf import OrderingColumn, PartitioningColumn, SelectedColumn  # noqa: F401
#      51 from pyspark.sql.udtf import SkipRestOfInputTableException  # noqa: F401
#      52 from pyspark.sql.udtf import UserDefinedTableFunction, _create_py_udtf
#
# ImportError: cannot import name 'AnalyzeArgument' from 'pyspark.sql.udtf' (d:\Learning And Development\Databricks\Declarative Automation Bundles\Course CI-CD with DAB\dab_project\.venv_pyspark\Lib\site-packages\pyspark\sql\udtf.py)

# %%
df = spark.createDataFrame([(1, "Alice"), (2, "Bob")], ["id", "name"])

# Use show() instead - safe method that displays directly
print("DataFrame contents:")
df.show()

# Check schema
print("\nDataFrame schema:")
df.printSchema()
# Out:
# DataFrame contents:
# +---+-----+
# | id| name|
# +---+-----+
# |  1|Alice|
# |  2|  Bob|
# +---+-----+
#
#
# DataFrame schema:
# root
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
